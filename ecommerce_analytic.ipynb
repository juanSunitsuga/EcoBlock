# %% [markdown]
# <a href="https://colab.research.google.com/github/juanSunitsuga/EcoBlock/blob/main/ecommerce_analytic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import os
import time

df = pd.read_csv("/content/data.csv", encoding="latin1")  # or "ISO-8859-1"
print(df.info())
print(df.describe())

df.to_csv("data.csv", index=False)
table = pa.Table.from_pandas(df)
pq.write_table(table, "ecommerce.parquet")
